# %%
from RQAOA import *
import networkx as nx
import matplotlib.pyplot as plt

# %%
graph = nx.random_regular_graph(3, 20, 42)
#graph = nx.complete_graph(10)
nx.set_edge_attributes(graph, values = 1, name = 'weight')

# %%
draw_graph(graph)

# %%
gm = GraphManager(graph, verbose = True)

# %%
best_cost, assignment = RQAOA(gm, 15)
# Out:
# Iter 0: Graph has 20 nodes and 30 edges remaining.
# QAOA Cost = 20.452821223446247. Anti-Correlating Edge (6, 18) that has maximum absolute weight -0.3840706564811159
# Removing edge (18, 6) with weight 1 from graph.
# Removing edge (17, 6) with weight 1 from graph.
# Removing edge (19, 6) with weight 1 from graph.
# Removing node 6 from graph.
# Adding edge (17, 18) with weight -1 to graph.
# Adding edge (19, 18) with weight -1 to graph.
# Iter 1: Graph has 19 nodes and 29 edges remaining.
# QAOA Cost = 17.849413897683267. Anti-Correlating Edge (13, 17) that has maximum absolute weight -0.49013614734882144
# Removing edge (17, 13) with weight 1 from graph.
# Removing edge (7, 13) with weight 1 from graph.
# Removing edge (18, 13) with weight 1 from graph.
# Removing node 13 from graph.
# Adding edge (7, 17) with weight -1 to graph.
# Adding edge (18, 17) with weight -2 to graph.
# Iter 2: Graph has 18 nodes and 27 edges remaining.
# QAOA Cost = 15.009868671687315. Correlating Edge (18, 17) that has maximum absolute weight 0.5497563478285314
# Removing edge (17, 18) with weight -2 from graph.
# Removing edge (0, 18) with weight 1 from graph.
# Removing edge (19, 18) with weight -1 from graph.
# Removing node 18 from graph.
# Adding edge (0, 17) with weight 1 to graph.
# Removing edge (19, 17) with weight 0 from graph.
# Iter 3: Graph has 17 nodes and 24 edges remaining.
# QAOA Cost = 15.54684413576289. Anti-Correlating Edge (5, 19) that has maximum absolute weight -0.4830435073277978
# Removing edge (19, 5) with weight 1 from graph.
# Removing edge (16, 5) with weight 1 from graph.
# Removing edge (11, 5) with weight 1 from graph.
# Removing node 5 from graph.
# Adding edge (16, 19) with weight -1 to graph.
# Adding edge (11, 19) with weight -1 to graph.
# Iter 4: Graph has 16 nodes and 23 edges remaining.
# QAOA Cost = 12.849491842388987. Correlating Edge (16, 19) that has maximum absolute weight 0.4285565448230355
# Removing edge (19, 16) with weight -1 from graph.
# Removing edge (15, 16) with weight 1 from graph.
# Removing edge (10, 16) with weight 1 from graph.
# Removing node 16 from graph.
# Adding edge (15, 19) with weight 1 to graph.
# Adding edge (10, 19) with weight 1 to graph.
# Iter 5: Graph has 15 nodes and 22 edges remaining.
# QAOA Cost = 13.113808241417187. Correlating Edge (17, 7) that has maximum absolute weight 0.42740859043730756
# Removing edge (7, 17) with weight -1 from graph.
# Removing edge (0, 17) with weight 1 from graph.
# Removing node 17 from graph.
# Adding edge (0, 7) with weight 1 to graph.
# Iter 6: Graph has 14 nodes and 21 edges remaining.
# QAOA Cost = 13.08137117421874. Anti-Correlating Edge (4, 15) that has maximum absolute weight -0.38124292697567014
# Removing edge (15, 4) with weight 1 from graph.
# Removing edge (8, 4) with weight 1 from graph.
# Removing edge (2, 4) with weight 1 from graph.
# Removing node 4 from graph.
# Adding edge (8, 15) with weight -1 to graph.
# Adding edge (2, 15) with weight -1 to graph.
# Iter 7: Graph has 13 nodes and 20 edges remaining.
# QAOA Cost = 10.469828921374713. Anti-Correlating Edge (10, 2) that has maximum absolute weight -0.4794687352337189
# Removing edge (2, 10) with weight 1 from graph.
# Removing edge (15, 10) with weight 1 from graph.
# Removing edge (19, 10) with weight 1 from graph.
# Removing node 10 from graph.
# Adding edge (15, 2) with weight -2 to graph.
# Adding edge (19, 2) with weight -1 to graph.
# Iter 8: Graph has 12 nodes and 18 edges remaining.
# QAOA Cost = 7.680561931248905. Correlating Edge (15, 2) that has maximum absolute weight 0.5613728252708834
# Removing edge (2, 15) with weight -2 from graph.
# Removing edge (19, 15) with weight 1 from graph.
# Removing edge (8, 15) with weight -1 from graph.
# Removing node 15 from graph.
# Removing edge (19, 2) with weight 0 from graph.
# Adding edge (8, 2) with weight -1 to graph.
# Iter 9: Graph has 11 nodes and 15 edges remaining.
# QAOA Cost = 8.342223028357683. Correlating Edge (8, 2) that has maximum absolute weight 0.564752259454755
# Removing edge (2, 8) with weight -1 from graph.
# Removing edge (14, 8) with weight 1 from graph.
# Removing edge (3, 8) with weight 1 from graph.
# Removing node 8 from graph.
# Adding edge (14, 2) with weight 1 to graph.
# Adding edge (3, 2) with weight 2 to graph.
# Iter 10: Graph has 10 nodes and 13 edges remaining.
# QAOA Cost = 8.727523492694363. Anti-Correlating Edge (3, 2) that has maximum absolute weight -0.7625702985263612
# Removing edge (2, 3) with weight 2 from graph.
# Removing edge (12, 3) with weight 1 from graph.
# Removing node 3 from graph.
# Adding edge (12, 2) with weight -1 to graph.
# Iter 11: Graph has 9 nodes and 12 edges remaining.
# QAOA Cost = 6.090532832185156. Correlating Edge (19, 11) that has maximum absolute weight 0.4751296358448627
# Removing edge (11, 19) with weight -1 from graph.
# Removing node 19 from graph.
# Iter 12: Graph has 8 nodes and 11 edges remaining.
# QAOA Cost = 6.395443890577491. Anti-Correlating Edge (11, 14) that has maximum absolute weight -0.4222015365250217
# Removing edge (14, 11) with weight 1 from graph.
# Removing edge (12, 11) with weight 1 from graph.
# Removing node 11 from graph.
# Adding edge (12, 14) with weight -1 to graph.
# Iter 13: Graph has 7 nodes and 10 edges remaining.
# QAOA Cost = 4.5239903522417775. Anti-Correlating Edge (14, 1) that has maximum absolute weight -0.3706535630413018
# Removing edge (1, 14) with weight 1 from graph.
# Removing edge (2, 14) with weight 1 from graph.
# Removing edge (12, 14) with weight -1 from graph.
# Removing node 14 from graph.
# Adding edge (2, 1) with weight -1 to graph.
# Adding edge (12, 1) with weight 1 to graph.
# Iter 14: Graph has 6 nodes and 9 edges remaining.
# QAOA Cost = 3.8077965690513516. Anti-Correlating Edge (12, 9) that has maximum absolute weight -0.3674851236401544
# Removing edge (9, 12) with weight 1 from graph.
# Removing edge (2, 12) with weight -1 from graph.
# Removing edge (1, 12) with weight 1 from graph.
# Removing node 12 from graph.
# Adding edge (2, 9) with weight 1 to graph.
# Adding edge (1, 9) with weight -1 to graph.
# Iter 15: Graph has 5 nodes and 8 edges remaining.
# QAOA Cost = 3.2826663734761743. Correlating Edge (1, 9) that has maximum absolute weight 0.3772201340274186
# Removing edge (9, 1) with weight -1 from graph.
# Removing edge (0, 1) with weight 1 from graph.
# Removing edge (7, 1) with weight 1 from graph.
# Removing edge (2, 1) with weight -1 from graph.
# Removing node 1 from graph.
# Adding edge (0, 9) with weight 2 to graph.
# Adding edge (7, 9) with weight 2 to graph.
# Removing edge (2, 9) with weight 0 from graph.
#
# Brute-Forcing
# Best reduced cost found so far is 0.0 for assignment [1, 1, 1, 1].
# Best reduced cost found so far is 4.0 for assignment [1, 1, 1, -1].
# Best Cost found for the original problem is 26.0.

# %%
draw_graph(graph)
